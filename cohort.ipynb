# %% [markdown]
# # Data Processing and Cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv(r"C:\Users\muham\OneDrive\Dokumen\DATA ANALYST\database\cohort\Online_Retail.csv")
data
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_23180\3883110609.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data =pd.read_csv(r"C:\Users\muham\OneDrive\Dokumen\DATA ANALYST\database\cohort\Online_Retail.csv")
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 397925    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 397926    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397930 entries, 0 to 397929
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397930 non-null  object
#  1   StockCode    397930 non-null  object
#  2   Description  397930 non-null  object
#  3   Quantity     397930 non-null  int64
#  4   InvoiceDate  397930 non-null  object
#  5   UnitPrice    397930 non-null  float64
#  6   CustomerID   397930 non-null  int64
#  7   Country      397930 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 24.3+ MB

# %%
data['InvoiceDate']=pd.to_datetime(data['InvoiceDate'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397930 entries, 0 to 397929
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397930 non-null  object
#  1   StockCode    397930 non-null  object
#  2   Description  397930 non-null  object
#  3   Quantity     397930 non-null  int64
#  4   InvoiceDate  397930 non-null  datetime64[ns]
#  5   UnitPrice    397930 non-null  float64
#  6   CustomerID   397930 non-null  int64
#  7   Country      397930 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 24.3+ MB

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom

# %% [markdown]
# # create an invoice month

# %%
import datetime as dt
def get_month(x):
    return dt.datetime(x.year, x.month,1)
data['InvoiceMonth']=data['InvoiceDate'].apply(get_month)
data.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 397925    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 397926    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 397927    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 397928    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 397929    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country InvoiceMonth
# 397925 2011-12-09 12:50:00       0.85       12680  France   2011-12-01
# 397926 2011-12-09 12:50:00       2.10       12680  France   2011-12-01
# 397927 2011-12-09 12:50:00       4.15       12680  France   2011-12-01
# 397928 2011-12-09 12:50:00       4.15       12680  France   2011-12-01
# 397929 2011-12-09 12:50:00       4.95       12680  France   2011-12-01

# %% [markdown]
# # Create a Column Index
# create a column index with the minimum invoice date aka first time customer was acquired

# %%
data['Cohort Month'] =  data.groupby('CustomerID')['InvoiceMonth'].transform('min')
data.head(30)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %% [markdown]
# # Create a date element function
# create a date element function to get a series for subtraction

# %%
def get_date_elements(df, column):
    day = df[column].dt.day
    month = df[column].dt.month
    year = df[column].dt.year
    return day, month, year

# %% [markdown]
# # Get date elements
# get date elements for our cohort and invoice columns

# %%
_,Invoice_month,Invoice_year =  get_date_elements(data,'InvoiceMonth')
_,Cohort_month,Cohort_year =  get_date_elements(data,'Cohort Month')

# %%
Cohort_year[:10]
# Out:
# 0    2010
# 1    2010
# 2    2010
# 3    2010
# 4    2010
# 5    2010
# 6    2010
# 7    2010
# 8    2010
# 9    2010
# Name: Cohort Month, dtype: int32

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country InvoiceMonth  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom   2010-12-01
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom   2010-12-01
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom   2010-12-01
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom   2010-12-01
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom   2010-12-01
#
#   Cohort Month
# 0   2010-12-01
# 1   2010-12-01
# 2   2010-12-01
# 3   2010-12-01
# 4   2010-12-01

# %% [markdown]
# # Create a cohort index

# %%
year_diff = Invoice_year -Cohort_year
month_diff = Invoice_month - Cohort_month
data['CohortIndex'] = year_diff*12+month_diff+1
data.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 397925    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 397926    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 397927    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 397928    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 397929    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country InvoiceMonth  \
# 397925 2011-12-09 12:50:00       0.85       12680  France   2011-12-01
# 397926 2011-12-09 12:50:00       2.10       12680  France   2011-12-01
# 397927 2011-12-09 12:50:00       4.15       12680  France   2011-12-01
# 397928 2011-12-09 12:50:00       4.15       12680  France   2011-12-01
# 397929 2011-12-09 12:50:00       4.95       12680  France   2011-12-01
#
#        Cohort Month  CohortIndex
# 397925   2011-08-01            5
# 397926   2011-08-01            5
# ...

# %% [markdown]
# # Count the customerID
# by grouping by Cohort Month  and Cohort Index

# %%
cohort_data = data.groupby(['Cohort Month','CohortIndex'])['CustomerID'].apply(pd.Series.nunique).reset_index()
cohort_data
# Out:
#    Cohort Month  CohortIndex  CustomerID
# 0    2010-12-01            1         885
# 1    2010-12-01            2         324
# 2    2010-12-01            3         286
# 3    2010-12-01            4         340
# 4    2010-12-01            5         321
# ..          ...          ...         ...
# 86   2011-10-01            2          86
# 87   2011-10-01            3          41
# 88   2011-11-01            1         324
# 89   2011-11-01            2          36
# 90   2011-12-01            1          41
#
# [91 rows x 3 columns]

# %% [markdown]
# # Create a pivot table

# %%
cohort_table = cohort_data.pivot(index='Cohort Month', columns=['CohortIndex'],values='CustomerID')
cohort_table
# Out:
# CohortIndex      1      2      3      4      5      6      7      8      9   \
# Cohort Month
# 2010-12-01    885.0  324.0  286.0  340.0  321.0  352.0  321.0  309.0  313.0
# 2011-01-01    417.0   92.0  111.0   96.0  134.0  120.0  103.0  101.0  125.0
# 2011-02-01    380.0   71.0   71.0  108.0  103.0   94.0   96.0  106.0   94.0
# 2011-03-01    452.0   68.0  114.0   90.0  101.0   76.0  121.0  104.0  126.0
# 2011-04-01    300.0   64.0   61.0   63.0   59.0   68.0   65.0   78.0   22.0
# 2011-05-01    284.0   54.0   49.0   49.0   59.0   66.0   75.0   27.0    NaN
# 2011-06-01    242.0   42.0   38.0   64.0   56.0   81.0   23.0    NaN    NaN
# 2011-07-01    188.0   34.0   39.0   42.0   51.0   21.0    NaN    NaN    NaN
# 2011-08-01    169.0   35.0   42.0   41.0   21.0    NaN    NaN    NaN    NaN
# 2011-09-01    299.0   70.0   90.0   34.0    NaN    NaN    NaN    NaN    NaN
# 2011-10-01    358.0   86.0   41.0    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %% [markdown]
# # Change index

# %%
cohort_table.index= cohort_table.index.strftime ('%B %Y')
plt.figure(figsize=(21,10))
sns.heatmap(cohort_table,annot=True,cmap= 'Blues')
# Out:
# <Axes: xlabel='CohortIndex', ylabel='Cohort Month'>

# %% [markdown]
# # Cohort table for percentage

# %%
new_cohort_table = cohort_table.divide(cohort_table.iloc[:,0],axis=0)
new_cohort_table
# Out:
# CohortIndex      1         2         3         4         5         6   \
# Cohort Month
# December 2010   1.0  0.366102  0.323164  0.384181  0.362712  0.397740
# January 2011    1.0  0.220624  0.266187  0.230216  0.321343  0.287770
# February 2011   1.0  0.186842  0.186842  0.284211  0.271053  0.247368
# March 2011      1.0  0.150442  0.252212  0.199115  0.223451  0.168142
# April 2011      1.0  0.213333  0.203333  0.210000  0.196667  0.226667
# May 2011        1.0  0.190141  0.172535  0.172535  0.207746  0.232394
# June 2011       1.0  0.173554  0.157025  0.264463  0.231405  0.334711
# July 2011       1.0  0.180851  0.207447  0.223404  0.271277  0.111702
# August 2011     1.0  0.207101  0.248521  0.242604  0.124260       NaN
# September 2011  1.0  0.234114  0.301003  0.113712       NaN       NaN
# October 2011    1.0  0.240223  0.114525       NaN       NaN       NaN
# November 2011   1.0  0.111111       NaN       NaN       NaN       NaN
# ...

# %% [markdown]
# # Create a percentages visual

# %%
plt.figure(figsize=(21,10))
sns.heatmap(new_cohort_table,annot=True,cmap='Greens',fmt='.0%')
# Out:
# <Axes: xlabel='CohortIndex', ylabel='Cohort Month'>

# %% [markdown]
# The purpose of cohort analysis is to observe behavioral trends or patterns of consumers over time.
# Each row represents a user or consumer group, and each column represents the month after the group was formed.
# The first month is the acquisition month. The values in the cells represent calculated analysis metrics.
# In this case, the data pertains to the number of consumers who made online retail purchases. The second month and subsequent months indicate the return of consumers for transactions. From the table, we can see a significant drop in the number of consumers in the second month, but from the third month onwards, the trend stabilizes. Interestingly, there is a consistent pattern of high transaction activity in November, as indicated by the diagonal line.
